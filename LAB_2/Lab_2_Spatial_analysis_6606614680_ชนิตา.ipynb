# %% [markdown]
# <a href="https://colab.research.google.com/github/chanita-lab/GE338-Code/blob/main/LAB_2/Lab_2_Spatial_analysis_6606614680_%E0%B8%8A%E0%B8%99%E0%B8%B4%E0%B8%95%E0%B8%B2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install earthengine-api geemap -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 20.6 MB/s eta 0:00:00

# %%
import ee
import geemap
import pandas as pd

ee.Authenticate()
ee.Initialize(project='ee-chanita')

# %%
provinces = ee.FeatureCollection("FAO/GAUL/2015/level1")

buriram = provinces \
    .filter(ee.Filter.eq('ADM0_NAME','Thailand')) \
    .filter(ee.Filter.eq('ADM1_NAME','Buriram'))

roi = buriram.geometry()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
def mask_clouds(image):
    scl = image.select('SCL')
    mask = scl.neq(3).And(scl.neq(8))
    return image.updateMask(mask)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
def add_indices(image):

    ndvi = image.normalizedDifference(['B8','B4']).rename('NDVI')

    ndmi = image.normalizedDifference(['B8','B11']).rename('NDMI')

    ndwi = image.normalizedDifference(['B3','B8']).rename('NDWI')

    return image.addBands([ndvi, ndmi, ndwi])
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
rainy = ee.ImageCollection('COPERNICUS/S2_SR_HARMONIZED') \
    .filterBounds(roi) \
    .filterDate('2020-08-01','2020-10-31') \
    .map(mask_clouds) \
    .median() \
    .clip(roi)

dry = ee.ImageCollection('COPERNICUS/S2_SR_HARMONIZED') \
    .filterBounds(roi) \
    .filterDate('2020-02-01','2020-04-30') \
    .map(mask_clouds) \
    .median() \
    .clip(roi)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
rainy = add_indices(rainy)
dry = add_indices(dry)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
ndvi_change = rainy.select('NDVI').subtract(dry.select('NDVI'))

ndmi_change = rainy.select('NDMI').subtract(dry.select('NDMI'))

ndwi_change = rainy.select('NDWI').subtract(dry.select('NDWI'))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
drought_risk = dry.select('NDVI').lt(0.3) \
    .And(dry.select('NDMI').lt(0)) \
    .clip(roi)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
water = dry.select('NDWI').gt(0.3).clip(roi)

moist_area = dry.select('NDMI').gt(0.2).clip(roi)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
Map = geemap.Map(center=[14.99,103.1], zoom=9)

Map.addLayer(
    dry.select('NDVI'),
    {'min':-1,'max':1,'palette':['brown','yellow','green']},
    'NDVI Dry'
)

Map.addLayer(
    ndvi_change,
    {'min':-1,'max':1,'palette':['red','white','green']},
    'NDVI Change'
)

Map.addLayer(
    drought_risk.updateMask(drought_risk),
    {'palette':['red']},
    'Drought Risk'
)

Map.addLayer(
    water.updateMask(water),
    {'palette':['blue']},
    'Water'
)

Map.addLayer(
    moist_area.updateMask(moist_area),
    {'palette':['cyan']},
    'Moist Area'
)

Map.addLayer(buriram,{'color':'black'},'Buriram')

Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[14.99, 103.1], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=SearchDataGU…

# %%
sample = dry.select(['NDVI','NDMI']).sample(
    region=roi,
    scale=30,
    numPixels=5000,
    geometries=False
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
df = geemap.ee_to_df(sample)

df.head()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#        NDMI      NDVI
# 0 -0.242893  0.159859
# 1  0.108402  0.643668
# 2 -0.145341  0.239336
# 3  0.068654  0.572682
# 4  0.111043  0.601908

# %%
correlation = df['NDVI'].corr(df['NDMI'])

print("Correlation between NDVI and NDMI =", correlation)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Correlation between NDVI and NDMI = 0.7896607184028762

# %%
import numpy as np
import matplotlib.pyplot as plt

z = np.polyfit(df['NDVI'], df['NDMI'], 1)
p = np.poly1d(z)

plt.figure(figsize=(6,6))
plt.scatter(df['NDVI'], df['NDMI'], s=5)

plt.plot(df['NDVI'], p(df['NDVI']), color='red')

plt.xlabel("NDVI")
plt.ylabel("NDMI")
plt.title("NDVI vs NDMI Relationship with Trend Line")

plt.show()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
task = ee.batch.Export.image.toDrive(
    image=dry.select('NDVI'),
    description='Buriram_NDVI',
    folder='GEE_exports',
    fileNamePrefix='buriram_ndvi',
    region=roi,
    scale=10,
    crs='EPSG:4326',
    fileFormat='GeoTIFF',
    maxPixels=1e13
)

task.start()

print(task.status())
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# {'state': 'READY', 'description': 'Buriram_NDVI', 'priority': 100, 'creation_timestamp_ms': 1774864711697, 'update_timestamp_ms': 1774864711697, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': '4BHUJYZWUTXBVFUZFQE7URVX', 'name': 'projects/ee-chanita/operations/4BHUJYZWUTXBVFUZFQE7URVX'}
